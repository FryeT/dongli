# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import sys
sys.path.append("..")

# %%
from DynamicLoop import DynamicLoop
import glob
import os
from file_sort_method import *

# %%
g375files = glob.glob('datas/0.1hz/*.csv')
g375files.sort(key=force_of_file)
for i , f in enumerate(g375files):
    print(i, f)
# Out:
# 0 datas/0.1hz\dl_G375_0.7kn2017-8-17(16-14-34).csv
# 1 datas/0.1hz\dl_G375_1.4kn2017-8-17(16-16-7).csv
# 2 datas/0.1hz\dl_G375_2.1kn2017-8-17(16-17-26).csv
# 3 datas/0.1hz\dl_G375_2.8kn2017-8-17(16-18-46).csv
# 4 datas/0.1hz\dl_G375_3.5kn2017-8-17(16-20-4).csv
# 5 datas/0.1hz\dl_G375_4.2kn2017-8-17(16-21-20).csv
# 6 datas/0.1hz\dl_G375_4.9kn2017-8-17(16-23-0).csv
# 7 datas/0.1hz\dl_G375_5.6kn2017-8-17(16-24-34).csv
# 8 datas/0.1hz\dl_G375_6.3kn2017-8-17(16-25-57).csv
# 9 datas/0.1hz\dl_G375_7kn2017-8-17(16-27-28).csv
# 10 datas/0.1hz\dl_G375_7.7kn2017-8-17(16-28-46).csv
# 11 datas/0.1hz\dl_G375_8.4kn2017-8-17(16-30-2).csv
# 12 datas/0.1hz\dl_G375_9.1kn2017-8-17(16-31-18).csv
# 13 datas/0.1hz\dl_G375_9.8kn2017-8-17(16-33-17).csv
# 14 datas/0.1hz\dl_G375_10.5kn2017-8-17(16-34-34).csv

# %%
plt.figure(figsize=(20,16), dpi=300)
plt.suptitle('G375 loops', fontsize=22)
for i, f in enumerate(g375files):
    df = pd.read_csv(f, encoding='gb2312')
    plt.subplot(5, 3, i+1)
    plt.plot(df['epsilon_d'], df['sigma_d'])
    plt.xlabel(r'$\varepsilon_d$', fontsize=16)
    plt.ylabel(r'$\sigma_d$ / kPa', fontsize=16)
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])

plt.savefig('loops.svg')

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import glob
files = glob.glob('datas/1hz/*.txt')
files.sort(key = lambda x: x[x.index('('):x.index(')')])

# %%
cols=['时间','振次','轴位移','力','应力','变形','侧位移','围压','孔压','反压','体变','小体变']
temp_df = pd.DataFrame(columns=cols)

# %%
for file in files:
    df = pd.read_table(file, encoding='gb2312')
    df.columns=cols
    temp_df = pd.concat([temp_df,df],ignore_index=True)
    
temp_df.drop(['侧位移','体变','小体变','应力'],1,inplace=True)
temp_df.dropna(inplace=True)
temp_df.to_csv('1hz.csv',index=False)

# %%
df = pd.read_csv('1hz.csv',encoding='gb2312')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400220 entries, 0 to 400219
# Data columns (total 8 columns):
# 时间     400220 non-null float64
# 振次     400220 non-null float64
# 轴位移    400220 non-null float64
# 力      400220 non-null float64
# 变形     400220 non-null float64
# 围压     400220 non-null float64
# 孔压     400220 non-null float64
# 反压     400220 non-null float64
# dtypes: float64(8)
# memory usage: 24.4 MB

# %%
plt.plot(df['轴位移'])

# %%
plt.plot(df['孔压'])

# %%
plt.plot(df['孔压'][100000:150000])

# %%
df1 = pd.read_csv('datas/dlG375_qd_14kn2017-8-22(10-23-12).csv')

# %%
plt.plot(df1['孔压'][:3000])
